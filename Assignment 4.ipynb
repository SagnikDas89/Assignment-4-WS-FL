# %%
1

# %%
# Importing Libraries
import pandas as pd
from bs4 import BeautifulSoup
import requests

#send get request to the webpage server to get the source code of the page
page = requests.get("https://en.wikipedia.org/wiki/List_of_most-viewed_YouTube_videos")

# page content
soup=BeautifulSoup(page.content)

# page content
soup=BeautifulSoup(page.content)

header_tags = [] # empty list
for header in soup.find_all(["td","td","td","td","td","td"]):
    header_tags.append(header.name+" "+header.text.strip())
    
# print all header_tags
header_tags
# Out:
# ['td ',
#  'td This article has multiple issues. Please help improve it or discuss these issues on the talk page. (Learn how and when to remove these template messages)\n\nThis article needs additional citations for verification. Please help improve this article by adding citations to reliable sources. Unsourced material may be challenged and removed.Find sources:\xa0"List of most-viewed YouTube videos"\xa0–\xa0news\xa0· newspapers\xa0· books\xa0· scholar\xa0· JSTOR (March 2021) (Learn how and when to remove this template message)\nThis article needs to be updated. Please update this article to reflect recent events or newly available information. (July 2021)\n\n (Learn how and when to remove this template message)',
#  'td ',
#  'td This article needs additional citations for verification. Please help improve this article by adding citations to reliable sources. Unsourced material may be challenged and removed.Find sources:\xa0"List of most-viewed YouTube videos"\xa0–\xa0news\xa0· newspapers\xa0· books\xa0· scholar\xa0· JSTOR (March 2021) (Learn how and when to remove this template message)',
#  'td ',
#  'td This article needs to be updated. Please update this article to reflect recent events or newly available information. (July 2021)',
#  'td ',
#  'td This section possibly contains original research. Please improve it by verifying the claims made and adding inline citations. Statements consisting only of original research should be removed. (March 2021) (Learn how and when to remove this template message)',
#  'td 1.',
#  'td "Baby Shark Dance"[22]',
#  "td Pinkfong Kids' Songs & Stories",
#  'td 9.06',
#  'td June 17, 2016',
#  'td [B]',
#  'td 2.',
#  'td "Despacito"[24]',
#  'td Luis Fonsi',
#  'td 7.47',
#  'td January 12, 2017',
#  'td [C]',
#  'td 3.',
#  'td "Johny Johny Yes Papa"[25]',
#  'td LooLoo Kids',
#  'td 5.60',
#  'td October 8, 2016',
#  'td [D]',
#  'td 4.',
#  'td "Shape of You"[26]',
#  'td Ed Sheeran',
#  'td 5.40',
#  'td January 30, 2017',
#  'td [E]',
#  'td 5.',
#  'td "See You Again"[27]',
#  'td Wiz Khalifa',
#  'td 5.20',
#  'td April 6, 2015',
#  'td [F]',
#  'td 6.',
#  'td "Masha and the Bear – Recipe for Disaster"[30]',
#  'td Get Movies',
#  'td 4.45',
#  'td January 31, 2012',
#  'td [G]',
#  'td 7.',
#  'td "Bath Song"[31]',
#  'td Cocomelon – Nursery Rhymes',
#  'td 4.39',
#  'td May 2, 2018',
#  'td [H]',
#  'td 8.',
#  'td "Learning Colors – Colorful Eggs on a Farm"[32]',
#  'td Miroshka TV',
#  'td 4.35',
#  'td February 27, 2018',
#  'td [I]',
#  'td 9.',
#  'td "Uptown Funk"[33]',
#  'td Mark Ronson',
#  'td 4.25',
#  'td November 19, 2014',
#  'td [J]',
#  'td 10.',
#  'td "Gangnam Style"[34]',
#  'td Psy',
#  'td 4.14',
#  'td July 15, 2012',
#  'td [K]',
#  'td 11.',
#  'td "Phonics Song with Two Words"[36]',
#  'td ChuChu TV',
#  'td 4.04',
#  'td March 6, 2014',
#  'td ',
#  'td 12.',
#  'td "Sugar"[37]',
#  'td Maroon 5',
#  'td 3.52',
#  'td January 14, 2015',
#  'td ',
#  'td 13.',
#  'td "Dame Tu Cosita"[38]',
#  'td El Chombo',
#  'td 3.49',
#  'td April 5, 2018',
#  'td ',
#  'td 14.',
#  'td "Sorry"[39]',
#  'td Justin Bieber',
#  'td 3.45',
#  'td October 22, 2015',
#  'td ',
#  'td 15.',
#  'td "Roar"[40]',
#  'td Katy Perry',
#  'td 3.40',
#  'td September 5, 2013',
#  'td ',
#  'td 16.',
#  'td "Counting Stars"[41]',
#  'td OneRepublic',
#  'td 3.35',
#  'td May 31, 2013',
#  'td ',
#  'td 17.',
#  'td "Thinking Out Loud"[42]',
#  'td Ed Sheeran',
#  'td 3.30',
#  'td October 7, 2014',
#  'td ',
#  'td 18.',
#  'td "Wheels on the Bus"[43]',
#  'td Cocomelon – Nursery Rhymes',
#  'td 3.20',
#  'td May 24, 2018',
#  'td ',
#  'td 19.',
#  'td "Dark Horse"[44]',
#  'td Katy Perry',
#  'td 3.11',
#  'td February 20, 2014',
#  'td ',
#  'td 20.',
#  'td "Faded"[45]',
#  'td Alan Walker',
#  'td 3.11',
#  'td December 3, 2015',
#  'td ',
#  'td 21.',
#  'td "Girls Like You"[46]',
#  'td Maroon 5',
#  'td 3.08',
#  'td May 31, 2018',
#  'td ',
#  'td 22.',
#  'td "Shake It Off"[47]',
#  'td Taylor Swift',
#  'td 3.08',
#  'td August 18, 2014',
#  'td ',
#  'td 23.',
#  'td "Lean On"[48]',
#  'td Major Lazer',
#  'td 3.07',
#  'td March 22, 2015',
#  'td ',
#  'td 24.',
#  'td "Bailando"[49]',
#  'td Enrique Iglesias',
#  'td 3.07',
#  'td April 11, 2014',
#  'td ',
#  'td 25.',
#  'td "Let Her Go"[50]',
#  'td Passenger',
#  'td 3.04',
#  'td July 25, 2012',
#  'td ',
#  'td 26.',
#  'td "Mi Gente"[51]',
#  'td J Balvin',
#  'td 2.95',
#  'td June 29, 2017',
#  'td ',
#  'td 27.',
#  'td "Perfect"[52]',
#  'td Ed Sheeran',
#  'td 2.91',
#  'td November 9, 2017',
#  'td ',
#  'td 28.',
#  'td "Axel F"[53]',
#  'td Crazy Frog',
#  'td 2.91',
#  'td June 16, 2009',
#  'td ',
#  'td 29.',
#  'td "Waka Waka (This Time for Africa)"[54]',
#  'td Shakira',
#  'td 2.90',
#  'td June 4, 2010',
#  'td ',
#  'td 30.',
#  'td "Hello"[55]',
#  'td Adele',
#  'td 2.86',
#  'td October 22, 2015',
#  'td ',
#  'td ',
#  'td This section possibly contains original research. Please improve it by verifying the claims made and adding inline citations. Statements consisting only of original research should be removed. (March 2021) (Learn how and when to remove this template message)',
#  'td "Tarzan Boy"[56]',
#  'td nailofgilead',
#  'td 0.22',
#  'td November 2, 2005',
#  'td ',
#  'td "Me at the zoo"[57]',
#  'td jawed',
#  'td 0.17',
#  'td April 23, 2005',
#  'td [M]',
#  'td "Life Goes On"[58]',
#  'td fhearnoiz',
#  'td 0.13',
#  'td September 22, 2005',
#  'td ',
#  'td "guitar"[59]',
#  'td guitar90',
#  'td 0.09',
#  'td December 20, 2005',
#  'td ',
#  'td "Hurt"[60]',
#  'td beachbuggy',
#  'td 0.09',
#  'td December 12, 2005',
#  'td ',
#  'td "Galinha Pintadinha – videoclip infantil animado"[63]',
#  'td Galinha Pintadinha',
#  'td 0.70',
#  'td December 28, 2006',
#  'td ',
#  'td "Ella y Yo"[64]',
#  'td JosephIngma',
#  'td 0.53',
#  'td April 27, 2006',
#  'td ',
#  'td "I Write Sins Not Tragedies"[65]',
#  'td Fueled By Ramen',
#  'td 0.35',
#  'td July 18, 2006',
#  'td ',
#  'td "Evolution of Dance"[66]',
#  'td Judson Laipply',
#  'td 0.31',
#  'td April 6, 2006',
#  'td ',
#  'td "Hit the Road Jack"[67]',
#  'td Andres Trevino',
#  'td 0.22',
#  'td June 3, 2006',
#  'td ',
#  'td "The Gummy Bear Song"[70]',
#  'td icanrockyourworld',
#  'td 2.51',
#  'td October 9, 2007',
#  'td ',
#  'td "Numb"[71]',
#  'td Linkin Park',
#  'td 1.64',
#  'td March 4, 2007',
#  'td ',
#  'td "Osito Gominola – Full Spanish Version – The Gummy Bear Song"[72]',
#  'td icanrockyourworld',
#  'td 1.10',
#  'td October 16, 2007',
#  'td ',
#  'td "Charlie Bit My Finger"[73]',
#  'td HDCYT',
#  'td 0.89',
#  'td May 22, 2007',
#  'td ',
#  'td "What I\'ve Done"[74]',
#  'td Linkin Park',
#  'td 0.53',
#  'td April 3, 2007',
#  'td ',
#  'td "Bohemian Rhapsody"[75]',
#  'td Queen',
#  'td 1.36',
#  'td August 1, 2008',
#  'td ',
#  'td "Hot n Cold"[76]',
#  'td Katy Perry',
#  'td 1.05',
#  'td October 13, 2008',
#  'td ',
#  'td "Pintinho Amarelinho – DVD Galena Pintadinha"[77]',
#  'td Galinha Pintadinha',
#  'td 0.93',
#  'td September 15, 2008',
#  'td ',
#  'td "Don\'t Stop Me Now"[78]',
#  'td Queen',
#  'td 0.70',
#  'td August 1, 2008',
#  'td ',
#  'td "Viva la Vida"[79]',
#  'td Coldplay',
#  'td 0.70',
#  'td August 4, 2008',
#  'td ',
#  'td "Axel F"[80]',
#  'td Crazy Frog',
#  'td 2.90',
#  'td June 16, 2009',
#  'td ',
#  'td "November Rain"[81]',
#  "td Guns N' Roses",
#  'td 1.68',
#  'td December 25, 2009',
#  'td ',
#  'td "Bad Romance"[82]',
#  'td Lady Gaga',
#  'td 1.42',
#  'td November 24, 2009',
#  'td ',
#  'td "Smells Like Teen Spirit"[83]',
#  'td Nirvana',
#  'td 1.31',
#  'td June 16, 2009',
#  'td ',
#  'td "Sweet Child o\' Mine"[84]',
#  "td Guns N' Roses",
#  'td 1.27',
#  'td December 25, 2009',
#  'td ',
#  'td "Waka Waka (This Time for Africa)"[54]',
#  'td Shakira',
#  'td 2.89',
#  'td June 4, 2010',
#  'td ',
#  'td "Baby"[85]',
#  'td Justin Bieber',
#  'td 2.54',
#  'td February 19, 2010',
#  'td ',
#  'td "Love the Way You Lie"[86]',
#  'td Eminem',
#  'td 2.26',
#  'td August 5, 2010',
#  'td ',
#  'td "Rolling in the Deep"[87]',
#  'td Adele',
#  'td 1.85',
#  'td November 30, 2010',
#  'td ',
#  'td "Twinkle Twinkle Little Star"[88]',
#  'td Super Simple Songs - Kids Songs',
#  'td 1.72',
#  'td September 5, 2010',
#  'td ',
#  'td "The Lazy Song"[89]',
#  'td Bruno Mars',
#  'td 2.17',
#  'td April 15, 2011',
#  'td ',
#  'td "Party Rock Anthem"[90]',
#  'td LMFAO',
#  'td 2.05',
#  'td March 8, 2011',
#  'td ',
#  'td "A Thousand Years"[91]',
#  'td Christina Perri',
#  'td 1.89',
#  'td October 26, 2011',
#  'td ',
#  'td "Hanuman Chalisa"[92]',
#  'td Gulshan Kumar & Hariharan via T-Series (Bhakti Sagar)',
#  'td 1.85',
#  'td May 10, 2011',
#  'td ',
#  'td "On the Floor"[93]',
#  'td Jennifer Lopez',
#  'td 1.77',
#  'td March 3, 2011',
#  'td ',
#  'td "Masha and the Bear – Recipe for Disaster"[30]',
#  'td Get Movies',
#  'td 4.45',
#  'td January 31, 2012',
#  'td ',
#  'td "Gangnam Style"[34]',
#  'td Psy',
#  'td 4.13',
#  'td July 15, 2012',
#  'td ',
#  'td "Let Her Go"[50]',
#  'td Passenger',
#  'td 3.03',
#  'td July 25, 2012',
#  'td ',
#  'td "Shake Shake The Mango Tree"[94]',
#  'td Sesame Street',
#  'td 1.87',
#  'td January 13, 2012',
#  'td ',
#  'td "Diamonds"[95]',
#  'td Rihanna',
#  'td 1.77',
#  'td November 8, 2012',
#  'td ',
#  'td "Roar"[40]',
#  'td Katy Perry',
#  'td 3.39',
#  'td September 5, 2013',
#  'td ',
#  'td "Counting Stars"[41]',
#  'td OneRepublic',
#  'td 3.35',
#  'td May 31, 2013',
#  'td ',
#  'td "Old MacDonald Had a Farm"[96]',
#  'td Bounce Patrol - Kids Songs',
#  'td 2.48',
#  'td November 12, 2013',
#  'td ',
#  'td "Rude"[97]',
#  'td Magic!',
#  'td 2.09',
#  'td December 5, 2013',
#  'td ',
#  'td "Wake Me Up"[98]',
#  'td Avicii',
#  'td 2.08',
#  'td July 29, 2013',
#  'td ',
#  'td "Uptown Funk"[33]',
#  'td Mark Ronson',
#  'td 4.24',
#  'td November 19, 2014',
#  'td ',
#  'td "Phonics Song with Two Words"[36]',
#  'td ChuChu TV',
#  'td 4.02',
#  'td March 6, 2014',
#  'td ',
#  'td "Thinking Out Loud"[42]',
#  'td Ed Sheeran',
#  'td 3.29',
#  'td October 7, 2014',
#  'td ',
#  'td "Dark Horse"[44]',
#  'td Katy Perry',
#  'td 3.11',
#  'td February 20, 2014',
#  'td ',
#  'td "Shake It Off"[47]',
#  'td Taylor Swift',
#  'td 3.08',
#  'td August 18, 2014',
#  'td ',
#  'td "See You Again"[27]',
#  'td Wiz Khalifa',
#  'td 5.19',
#  'td April 6, 2015',
#  'td ',
#  'td "Sugar"[37]',
#  'td Maroon 5',
#  'td 3.51',
#  'td January 14, 2015',
#  'td ',
#  'td "Sorry"[39]',
#  'td Justin Bieber',
#  'td 3.45',
#  'td October 22, 2015',
#  'td ',
#  'td "Faded"[45]',
#  'td Alan Walker',
#  'td 3.10',
#  'td December 3, 2015',
#  'td ',
#  'td "Lean On"[48]',
#  'td Major Lazer',
#  'td 3.07',
#  'td March 22, 2015',
#  'td ',
#  'td "Baby Shark Dance"[22]',
#  "td Pinkfong Kids' Songs & Stories",
#  'td 9.04',
#  'td June 17, 2016',
#  'td [N]',
#  'td "Johny Johny Yes Papa"[25]',
#  'td LooLoo Kids',
#  'td 5.58',
#  'td October 8, 2016',
#  'td ',
#  'td "Closer (Lyric video)"[99]',
#  'td The Chainsmokers',
#  'td 2.69',
#  'td July 29, 2016',
#  'td ',
#  'td "We Don\'t Talk Anymore"[100]',
#  'td Charlie Puth',
#  'td 2.68',
#  'td August 2, 2016',
#  'td ',
#  'td "Chantaje"[101]',
#  'td Shakira',
#  'td 2.66',
#  'td November 18, 2016',
#  'td ',
#  'td "Despacito"[24]',
#  'td Luis Fonsi',
#  'td 7.46',
#  'td January 12, 2017',
#  'td [O]',
#  'td "Shape of You"[26]',
#  'td Ed Sheeran',
#  'td 5.40',
#  'td January 30, 2017',
#  'td ',
#  'td "Mi Gente"[51]',
#  'td J Balvin',
#  'td 2.95',
#  'td June 29, 2017',
#  'td ',
#  'td "Perfect"[52]',
#  'td Ed Sheeran',
#  'td 2.90',
#  'td November 9, 2017',
#  'td ',
#  'td "New Rules"[102]',
#  'td Dua Lipa',
#  'td 2.48',
#  'td July 7, 2017',
#  'td ',
#  'td "Bath Song"[31]',
#  'td Cocomelon – Nursery Rhymes',
#  'td 4.37',
#  'td May 2, 2018',
#  'td ',
#  'td "Learning Colors – Colorful Eggs on a Farm"[32]',
#  'td Miroshka TV',
#  'td 4.31',
#  'td February 27, 2018',
#  'td ',
#  'td "Dame Tu Cosita"[38]',
#  'td Ultra Music',
#  'td 3.48',
#  'td April 5, 2018',
#  'td ',
#  'td "Wheels on the Bus"[103]',
#  'td Cocomelon – Nursery Rhymes',
#  'td 3.18',
#  'td May 24, 2018',
#  'td ',
#  'td "Girls Like You"[46]',
#  'td Maroon 5',
#  'td 3.08',
#  'td May 31, 2018',
#  'td ',
#  'td "Con Calma"[104]',
#  'td Daddy Yankee',
#  'td 2.32',
#  'td January 23, 2019',
#  'td ',
#  'td "Keysha Play Filling Water in Balloons"[105]',
#  'td Zuni and Family',
#  'td 2.10',
#  'td April 21, 2019',
#  'td ',
#  'td "Con Altura"[106]',
#  'td Rosalía',
#  'td 1.84',
#  'td March 28, 2019',
#  'td ',
#  'td "China"[107]',
#  'td Anuel AA',
#  'td 1.74',
#  'td July 19, 2019',
#  'td ',
#  'td "Dance Monkey"[108]',
#  'td Tones and I',
#  'td 1.64',
#  'td June 24, 2019',
#  'td ',
#  'td "Life Is Good"[109]',
#  'td Future',
#  'td 1.94',
#  'td January 10, 2020',
#  'td ',
#  'td "Shake, shake your body! Clap, Clap, Cha Cha Cha!"[110]',
#  'td D Billions',
#  'td 1.82',
#  'td January 12, 2020',
#  'td ',
#  'td "Yummy Fruits & Vegetables"[111]',
#  'td D Billions',
#  'td 1.33',
#  'td September 16, 2020',
#  'td ',
#  'td "Dynamite"[112]',
#  'td BTS',
#  'td 1.18',
#  'td August 20, 2020',
#  'td ',
#  'td "52 Gaj Ka Daman"[113]',
#  'td Desi Records',
#  'td 1.09',
#  'td October 8, 2020',
#  'td ',
#  'td "Lut Gaye"[114]',
#  'td T-Series',
#  'td 0.87',
#  'td February 21, 2021',
#  'td ',
#  'td "Butter"[115]',
#  'td BTS',
#  'td 0.48',
#  'td May 20, 2021',
#  'td ',
#  'td "Save Your Tears"[116]',
#  'td The Weeknd',
#  'td 0.45',
#  'td January 5, 2021',
#  'td ',
#  'td "Saiyaan Ji"[117]',
#  'td T-Series',
#  'td 0.43',
#  'td January 27, 2021',
#  'td ',
#  'td "Munna Ro Raha Tha - Crying Baby Song"[118]',
#  'td Infobells Hindi',
#  'td 0.42',
#  'td March 3, 2021',
#  'td ',
#  'td "Baby Shark Dance"[22]',
#  "td Pinkfong! Kids' Songs & Stories",
#  'td 7,037,500,000',
#  'td June 17, 2016',
#  'td November 2, 2020',
#  'td 275',
#  'td ',
#  'td ',
#  'td "Despacito"[24]',
#  'td Luis Fonsi',
#  'td 2,993,700,000',
#  'td January 12, 2017',
#  'td August 4, 2017',
#  'td 1,186',
#  'td [119]',
#  'td [P]',
#  'td "See You Again"[27]',
#  'td Wiz Khalifa',
#  'td 2,894,000,000',
#  'td April 6, 2015',
#  'td July 10, 2017',
#  'td 25',
#  'td [28]',
#  'td ',
#  'td "Gangnam Style"⁂[34]',
#  'td Psy',
#  'td 803,700,000',
#  'td July 15, 2012',
#  'td November 24, 2012',
#  'td 1,689',
#  'td [35]',
#  'td [Q]',
#  'td "Baby"*[85]',
#  'td Justin Bieber',
#  'td 245,400,000',
#  'td February 19, 2010',
#  'td July 16, 2010',
#  'td 862',
#  'td [120]',
#  'td [R]',
#  'td "Bad Romance"[82]',
#  'td Lady Gaga',
#  'td 178,400,000',
#  'td November 24, 2009',
#  'td April 14, 2010',
#  'td 93',
#  'td [123]',
#  'td [S]',
#  'td "Charlie Bit My Finger"‡[73]',
#  'td HDCYT',
#  'td 128,900,000',
#  'td May 22, 2007',
#  'td October 25, 2009',
#  'td 171',
#  'td [126]',
#  'td ',
#  'td "Evolution of Dance"[66]',
#  'td Judson Laipply',
#  'td 118,900,000',
#  'td April 6, 2006',
#  'td May 2, 2009',
#  'td 176',
#  'td [127]',
#  'td ',
#  'td "Girlfriend"‡[128][129]',
#  'td RCA Records',
#  'td 92,600,000',
#  'td February 27, 2007',
#  'td July 17, 2008',
#  'td 289',
#  'td [130]',
#  'td ',
#  'td "Evolution of Dance"[66]',
#  'td Judson Laipply',
#  'td 78,400,000',
#  'td April 6, 2006',
#  'td March 15, 2008',
#  'td 124',
#  'td [131]',
#  'td ',
#  'td "Music Is My Hot Hot Sex"‡[132]',
#  'td CLARUSBARTEL72',
#  'td 76,600,000',
#  'td April 9, 2007',
#  'td March 1, 2008',
#  'td 14',
#  'td [133]',
#  'td [T]',
#  'td "Evolution of Dance"*[66]',
#  'td Judson Laipply',
#  'td 10,600,000',
#  'td April 6, 2006',
#  'td May 19, 2006',
#  'td 652',
#  'td [136]',
#  'td [U]',
#  'td "Pokemon Theme Music Video"‡[137]',
#  'td Smosh',
#  'td 4,300,000',
#  'td November 28, 2005',
#  'td March 12, 2006',
#  'td 68',
#  'td [138]',
#  'td [V]',
#  'td "Myspace – The Movie"‡[141][142]',
#  'td eggtea',
#  'td 2,700,000',
#  'td January 31, 2006',
#  'td February 18, 2006',
#  'td 22',
#  'td [143]',
#  'td ',
#  'td "Phony Photo Booth"‡[144]',
#  'td mugenized',
#  'td 3,400,000',
#  'td December 1, 2005',
#  'td January 21, 2006',
#  'td 28',
#  'td [145]',
#  'td [W]',
#  'td "The Chronic of Narnia Rap"‡[146]',
#  'td youtubedude',
#  'td 2,300,000',
#  'td December 18, 2005',
#  'td January 9, 2006',
#  'td 12',
#  'td [147]',
#  'td ',
#  'td "Ronaldinho: Touch of Gold"‡*[148]',
#  'td Nikesoccer',
#  'td 255,000',
#  'td October 21, 2005',
#  'td October 31, 2005',
#  'td 70',
#  'td [149]',
#  'td [X]',
#  'td "I/O Brush"‡*[151]',
#  'td larfus',
#  'td 247,000',
#  'td October 5, 2005',
#  'td October 29, 2005',
#  'td 2',
#  'td [152]',
#  'td ',
#  'td "Me at the zoo"[57]',
#  'td jawed',
#  'td 1',
#  'td April 23, 2005',
#  'td April 23, 2005',
#  'td 1',
#  'td [153]',
#  'td ',
#  'td History\nSocial impact',
#  'td Current\nSusan Wojcicki (CEO)\nLyor Cohen\nSusanne Daniels\nJohn Farrell\nRobert Kyncl\nFormer\nSteve Chen (Founder)\nChad Hurley (Founder)\nSalar Kamangar\nJawed Karim (Founder)\nUdi Manber\nYu Pan',
#  'td Susan Wojcicki (CEO)\nLyor Cohen\nSusanne Daniels\nJohn Farrell\nRobert Kyncl',
#  'td Steve Chen (Founder)\nChad Hurley (Founder)\nSalar Kamangar\nJawed Karim (Founder)\nUdi Manber\nYu Pan',
#  'td ',
#  'td Most-subscribed channels\nMusic artists\nMost-viewed channels\nMulti-channel network (list)\nOfficial channel\nOriginal channels',
#  "td BookTube\nBreadTube\nCharlie Bit My Finger\nCreator Awards\nDraw My Life\nLet's Play\nMe at the zoo\nPewDiePie vs T-Series\nReply girl\nViral video\nYouTube Poop\nYouTube Rewind\n2018\n2019\nYouTuber\nlist\nVirtual YouTuber\nLists\nMost-viewed videos\n24 hours\nArabic music videos\nFrench music videos\nIndian videos\nPakistani music videos\nMost-liked videos\nMost-disliked videos\nBy decade\n2000s YouTube videos\n2010s YouTube videos\n2020s YouTube videos",
#  "td BookTube\nBreadTube\nCharlie Bit My Finger\nCreator Awards\nDraw My Life\nLet's Play\nMe at the zoo\nPewDiePie vs T-Series\nReply girl\nViral video\nYouTube Poop\nYouTube Rewind\n2018\n2019\nYouTuber\nlist\nVirtual YouTuber",
#  'td Most-viewed videos\n24 hours\nArabic music videos\nFrench music videos\nIndian videos\nPakistani music videos\nMost-liked videos\nMost-disliked videos',
#  'td 2000s YouTube videos\n2010s YouTube videos\n2020s YouTube videos',
#  'td Backdoor advertisement controversy in Korea\nCensorship\nCopyright issues\nContent ID\nCopyright strike\nElsagate\nFantastic Adventures scandal\nGarcia v. Google, Inc.\nKohistan video case\nLenz v. Universal Music Corp.\nPrivacy\nReactions to Innocence of Muslims\nSlovenian government incident\nViacom International Inc. v. YouTube, Inc.',
#  'td Kids\nMusic\nPremium (original programming)\nTV',
#  'td Awards\nCNN/YouTube presidential debates\nComedy Week\nKSI vs. Logan Paul\nrematch\nLive\nMusic Awards\n2013\n2015\nPlaylist Live\nProject for Awesome\nSocial in the City\nSpace Lab\nSymphony Orchestra\nInternet Symphony No. 1\nMothership\nTubecon\nVidCon',
#  'td API\nCensorship of YouTube\nGermany\nGoogle Preferred\nVevo\nYouTube HQ shooting\nYouTube in education\nYouTube Instant\nYouTube Space\nYouTube suspensions',
#  'td Most-followed Facebook pages\nMost-followed Instagram accounts\nMost-followed TikTok accounts\nMost-followed Twitch channels\nMost-followed Twitter accounts\nYouTube channels\nMost-subscribed\nMost-viewed',
#  'td Most-liked Instagram posts\nMost-liked TikTok videos\nTweets\nMost-liked\nMost-retweeted\nMost-viewed online videos in the first 24 hours\nYouTube videos\nMost-liked\nMost-viewed\nMost-disliked']

# %%
2

# %%
# lets now import all the required libraries
from bs4 import BeautifulSoup
import selenium
from geopy.exc import GeocoderTimedOut
from geopy.geocoders import Nominatim
import pandas as pd
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
import time
import requests
import os
from selenium.webdriver.common.by import By
from selenium.webdriver.support.ui import WebDriverWait, Select
from selenium.webdriver.support import expected_conditions as EC
from selenium.common.exceptions import TimeoutException
from PIL import Image
from math import ceil
import io
import hashlib
import pandas as pd
import numpy as np
import json
from selenium.common.exceptions import NoSuchElementException           # Importing Exceptions
#Importing requests
import requests
# importing regex
import re

# %%
# Lets first connect to the web driver
driver = webdriver.Chrome("chromedriver.exe")

# %%
url = 'https://www.bcci.tv/'
driver.get(url)

# %%
international = driver.find_element_by_xpath("//div[@class='navigation__drop-down drop-down drop-down--reveal-on-hover']")
international.click()
time.sleep(1)

titles_tags=driver.find_elements_by_xpath("//div[@class='event-list__list']")
titles_tags
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="d6448fa780839337b2d31d2f84029c80", element="7772fefd-8d0e-459e-bda3-43af9c10852e")>]

# %%
# so we will run a loop to iterate over the tags extracted above and extract the text inside them.
fixturemonth_titles=[]
for i in titles_tags:
    fixturemonth_titles.append(i.text)
fixturemonth_titles
# Out:
# ["August 2021\nWednesday\n04\nAUGUST\n15:30 IST\nTEST\nENGLAND V INDIA 2021\n1st Test\nTrent Bridge, Nottingham\nENGLAND\nv\nINDIA\nMATCH CENTRE\nLIVE\nThursday\n12\nAUGUST\n15:30 IST\nTEST\nENGLAND V INDIA 2021\n2nd Test\nLord's, London\nENGLAND\nv\nINDIA\nMATCH CENTRE\nWednesday\n25\nAUGUST\n15:30 IST\nTEST\nENGLAND V INDIA 2021\n3rd Test\nHeadingley, Leeds\nENGLAND\nv\nINDIA\nMATCH CENTRE\nSeptember 2021\nThursday\n02\nSEPTEMBER\n15:30 IST\nTEST\nENGLAND V INDIA 2021\n4th Test\nThe Oval, London\nENGLAND\nv\nINDIA\nMATCH CENTRE\nFriday\n10\nSEPTEMBER\n15:30 IST\nTEST\nENGLAND V INDIA 2021\n5th Test\nOld Trafford, Manchester\nENGLAND\nv\nINDIA\nMATCH CENTRE"]

# %%
4

# %%
# Activating the chrome browser
driver=webdriver.Chrome("chromedriver.exe") 
time.sleep(3)

# Opening the homepage of statisticstimes.com
url = "http://statisticstimes.com/"
driver.get(url)

# %%
search_button = driver.find_element_by_xpath('//div[@class="cc-window cc-banner cc-type-info cc-theme-block cc-bottom cc-color-override-688238583 "]')     
search_button.click()  

titles_tags=driver.find_elements_by_xpath("//a[@class='ec']")
titles_tags
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="b4a0f32a58b592402fc9a8b1f51e4cdb", element="a59bd974-4f47-4727-90d1-cd2de051310b")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="b4a0f32a58b592402fc9a8b1f51e4cdb", element="d85a7bb8-6691-4efd-9075-9f3dffe76f45")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="b4a0f32a58b592402fc9a8b1f51e4cdb", element="83198aa1-062c-40e7-95d6-50f7a46c53fc")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="b4a0f32a58b592402fc9a8b1f51e4cdb", element="66fac915-6c7b-4103-a196-fd9c1c907cd8")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="b4a0f32a58b592402fc9a8b1f51e4cdb", element="54560613-adbf-436f-92a7-4e18582742a9")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="b4a0f32a58b592402fc9a8b1f51e4cdb", element="6c80d8fa-a886-4757-87a6-3eb2172934ca")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="b4a0f32a58b592402fc9a8b1f51e4cdb", element="18bd5a86-32f3-4f6a-9464-96c28154142b")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="b4a0f32a58b592402fc9a8b1f51e4cdb", element="bb7891eb-cc4d-4ed1-a4a9-1af5ddc6ffbc")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="b4a0f32a58b592402fc9a8b1f51e4cdb", element="3732e2b8-db83-476e-b11d-dc4242f7445b")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="b4a0f32a58b592402fc9a8b1f51e4cdb", element="678518ce-01cd-4939-9205-6f89d9a15aef")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="b4a0f32a58b592402fc9a8b1f51e4cdb", element="a43224bf-cf1c-4cd3-b69a-e33681ba1d19")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="b4a0f32a58b592402fc9a8b1f51e4cdb", element="891664fc-d932-49f9-82f7-5f8717982393")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="b4a0f32a58b592402fc9a8b1f51e4cdb", element="d450db88-9a3c-4999-bedc-68b4233b1a96")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="b4a0f32a58b592402fc9a8b1f51e4cdb", element="68202486-fb73-4518-8671-0c8a185d81ed")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="b4a0f32a58b592402fc9a8b1f51e4cdb", element="24354191-6984-4093-a5b9-c6e615336d54")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="b4a0f32a58b592402fc9a8b1f51e4cdb", element="646d84d3-a65a-47f7-87be-45433e15ec57")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="b4a0f32a58b592402fc9a8b1f51e4cdb", element="be76262a-0521-4fe9-a72e-ce8070f5345c")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="b4a0f32a58b592402fc9a8b1f51e4cdb", element="4bd595cf-b658-4262-88c3-6601931c3213")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="b4a0f32a58b592402fc9a8b1f51e4cdb", element="f59c405b-1b26-494f-b85c-a0306c3325b0")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="b4a0f32a58b592402fc9a8b1f51e4cdb", element="f5b57fa2-b651-4c10-965b-e547b67548ad")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="b4a0f32a58b592402fc9a8b1f51e4cdb", element="cc4a0f9e-1e60-4442-abc3-4a161325b27e")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="b4a0f32a58b592402fc9a8b1f51e4cdb", element="e80ec7ad-bd85-4aee-89ce-b1d3646fde79")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="b4a0f32a58b592402fc9a8b1f51e4cdb", element="6d838622-1793-46f6-8d5f-088f405473e5")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="b4a0f32a58b592402fc9a8b1f51e4cdb", element="e654d9c6-3ae3-4c4a-a8ff-75c1450cd2f3")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="b4a0f32a58b592402fc9a8b1f51e4cdb", element="9c22817a-43a8-4754-ab8f-629291829d62")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="b4a0f32a58b592402fc9a8b1f51e4cdb", element="76cf707c-e9aa-4a4b-b6c1-45102a962e0a")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="b4a0f32a58b592402fc9a8b1f51e4cdb", element="5d62adaa-3021-49d4-b1b8-fa3eb2a6aa6e")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="b4a0f32a58b592402fc9a8b1f51e4cdb", element="30f694f8-dd34-467e-b77d-335918658ebe")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="b4a0f32a58b592402fc9a8b1f51e4cdb", element="18d0315f-2d34-4f83-835b-9069420fe5e4")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="b4a0f32a58b592402fc9a8b1f51e4cdb", element="71673807-2816-410f-b92e-136bd09d5e1f")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="b4a0f32a58b592402fc9a8b1f51e4cdb", element="4f9da18a-9a86-44db-baee-f30e2a34bd8b")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="b4a0f32a58b592402fc9a8b1f51e4cdb", element="00c22995-d12e-41c2-8659-6ade5fb2031e")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="b4a0f32a58b592402fc9a8b1f51e4cdb", element="16983273-0b57-45b2-8d41-8e9d8be7fe91")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="b4a0f32a58b592402fc9a8b1f51e4cdb", element="f40e1094-c22e-4cd1-ae94-5a650802ae75")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="b4a0f32a58b592402fc9a8b1f51e4cdb", element="e4b01ef0-b475-47e1-b390-54addf6d72be")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="b4a0f32a58b592402fc9a8b1f51e4cdb", element="633cf744-fce9-417e-9ee5-ca9709b54b96")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="b4a0f32a58b592402fc9a8b1f51e4cdb", element="73678219-0754-447b-9ad9-643540400327")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="b4a0f32a58b592402fc9a8b1f51e4cdb", element="842374b5-dc61-44dd-9d74-ebf38f52e002")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="b4a0f32a58b592402fc9a8b1f51e4cdb", element="08ac68b6-69b2-4d5f-8081-62b746684f82")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="b4a0f32a58b592402fc9a8b1f51e4cdb", element="f86a8f50-5ff0-40aa-828a-9b03bfc98f85")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="b4a0f32a58b592402fc9a8b1f51e4cdb", element="f1ff2c5d-9766-4266-9ea4-33358b5fd51e")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="b4a0f32a58b592402fc9a8b1f51e4cdb", element="c5d7e459-7fd1-4d12-b04a-6fa00fbbc498")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="b4a0f32a58b592402fc9a8b1f51e4cdb", element="3cd82bb9-dd94-4a64-a151-f6ba7ee17fad")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="b4a0f32a58b592402fc9a8b1f51e4cdb", element="de41d60a-9bc8-4028-8801-19cf1128cb42")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="b4a0f32a58b592402fc9a8b1f51e4cdb", element="8633096a-077e-439f-be6b-4bb2b923c940")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="b4a0f32a58b592402fc9a8b1f51e4cdb", element="2adfce2b-29cf-4ad1-bcf2-e55cf7257336")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="b4a0f32a58b592402fc9a8b1f51e4cdb", element="ce550c2e-c054-46d1-bac1-9d0081d39619")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="b4a0f32a58b592402fc9a8b1f51e4cdb", element="70d352d3-02a0-4aea-8260-561223e5ab35")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="b4a0f32a58b592402fc9a8b1f51e4cdb", element="79daee1e-4fb5-491a-8b7e-070aa073e206")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="b4a0f32a58b592402fc9a8b1f51e4cdb", element="13c861d8-edcd-422a-b6a2-ee9278225e00")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="b4a0f32a58b592402fc9a8b1f51e4cdb", element="21615dc4-8c32-4c67-8975-105b0b2573be")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="b4a0f32a58b592402fc9a8b1f51e4cdb", element="3f3a3cc3-ba3e-494f-bccc-55624d59fd50")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="b4a0f32a58b592402fc9a8b1f51e4cdb", element="53648059-0a21-42f3-9cff-ccbff91be633")>]

# %%
# so we will run a loop to iterate over the tags extracted above and extract the text inside them.
gdp_titles=[]
for i in titles_tags:

    gdp_titles.append(i.text)
gdp_titles
# Out:
# ['» Quarterly GDP Growth of India',
#  '» GDP of India',
#  '» GDP per capita of India',
#  '» GDP Growth of India',
#  '» Sectorwise GDP of India',
#  '» Sectorwise GDP Growth of India',
#  '» Agriculture Sector in India',
#  '» Industry Sector in India',
#  '» Manufacturing Sector in India',
#  '» Mining and Quarrying Sector in India',
#  '» Services Sector in India',
#  '» Indian rupee historical exchange rate',
#  '» Indian rupee performance year wise',
#  '» GDP of Indian states',
#  '» GDP per capita of Indian states',
#  '» GDP Growth of Indian states',
#  '» GDP per capita Growth of Indian states',
#  '» Comparing Indian states and Countries by GDP',
#  '» Sectorwise GDP of Indian states',
#  '» GDP-Population-Area relationship of Indian states',
#  '» Economy of A & N Islands',
#  '» Economy of Andhra Pradesh',
#  '» Economy of Arunachal Pradesh',
#  '» Economy of Assam',
#  '» Economy of Bihar',
#  '» Economy of Chandigarh',
#  '» Economy of Chhattisgarh',
#  '» Economy of Delhi',
#  '» Economy of Goa',
#  '» Economy of Gujarat',
#  '» Economy of Haryana',
#  '» Economy of Himachal Pradesh',
#  '» Economy of Jammu & Kashmir',
#  '» Economy of Jharkhand',
#  '» Economy of Karnataka',
#  '» Economy of Kerala',
#  '» Economy of Madhya Pradesh',
#  '» Economy of Maharashtra',
#  '» Economy of Manipur',
#  '» Economy of Meghalaya',
#  '» Economy of Mizoram',
#  '» Economy of Nagaland',
#  '» Economy of Odisha',
#  '» Economy of Puducherry',
#  '» Economy of Punjab',
#  '» Economy of Rajasthan',
#  '» Economy of Sikkim',
#  '» Economy of Tamil Nadu',
#  '» Economy of Telangana',
#  '» Economy of Tripura',
#  '» Economy of Uttar Pradesh',
#  '» Economy of Uttarakhand',
#  '» Economy of West Bengal']

# %%
9

# %%
from bs4 import BeautifulSoup
import requests
import re
import pandas as pd

url = 'https://www.imdb.com/list/ls095964455/'
response = requests.get(url)
soup = BeautifulSoup(response.text, 'lxml')

tv_series = soup.select('td.titleColumn')
names = [a.attrs.get('href') for a in soup.select('lister-item-header h3')]
year_span = [a.attrs.get('title') for a in soup.select('lister-item-header span')]
genre = [a.attrs.get('genre') for a in soup.select('text-muted text-small span')]
runtime = [b.atters.get('runtime') for b in soup.select('text-muted text-small span')]
ratings = [b.attrs.get('data-value') for b in soup.select('td.posterColumn span[name=ir]')]
votes = [b.attrs.get('data-value') for b in soup.select('td.ratingColumn strong')]


list = []

for index in range(0, len(tv_series)):
    tv_series_string = tv_series[index].get_text()
    tv_series = (' '.join(tv_series_string.split()).replace('.', ''))
    tv_series_title = movie[len(str(index))+1:-7]
    year_span = re.search('\((.*?)\)', tv_series_string).group(1)
    genre = tv_series[:len(str(index))-(len(tv_series))]
    
    data = pd.DataFrame({"tv_series_title": tv_series_title,
            "year_span": year_span,
            "genre": genre,
            "runtime": runtime[index],
            "ratings": ratings[index],
            "votes": votes[index],})
    list.append(data)
    
    for tv_series in list:
        print(tv_series['place'], '-', tv_series['tv_series_title'], '('+tv_series['year_span'] +
          ') -', 'genre:', tv_series['runtime'], tv_series['rating'])
